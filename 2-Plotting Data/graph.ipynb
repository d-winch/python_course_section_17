# %%
# Making a basic Bokeh graph

from bokeh.models import HoverTool
from bokeh.plotting import figure
from bokeh.io import output_notebook, output_file, show
import pandas
import sys

df = pandas.read_csv("bachelors.csv")

# Prepare the output
if sys.stdin.isatty():
    output_file("bachelors_graph.html")
else:
    output_notebook()

# Create figure object
f = figure(title="Percentage of women who have received a bachelor's degree in engineering by year",
           plot_width=900,
           plot_height=500)

# Create line plot
f.line(x=df["Year"], y=df["Engineering"], line_width=1)
f.add_tools(HoverTool(tooltips=[("Year", "@x"), ("Engineering %", "@y")]))

# Display
show(f)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="622c526f-ec18-4188-9f3f-76819b2d2d8c">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="a0024a40-bec8-4424-93dd-675d13365149"></div>
